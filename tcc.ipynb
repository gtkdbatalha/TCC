# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
#estudantes = csv.reader(open("Estudantes_CRP_tratado.csv"),delimiter=';')
#historico  = csv.reader(open("Historico_CRP.csv"),delimiter=';')
estudantes = pd.read_csv(("Estudantes_CRP_tratado.csv"),delimiter=';', low_memory=False)
historico = pd.read_csv(("Historico_CRP.csv"),delimiter=';')
historicoV = pd.read_csv(("CRP_HistVelho.csv"),delimiter=';', low_memory=False)

# %%
CRPhisV = pd.DataFrame(historicoV)

# %%
CRPinfo = pd.DataFrame(estudantes)
CRPhis = pd.DataFrame(historico)

# %%
CRPhisNovo = pd.concat([CRPhisV, CRPhis], axis=0, verify_integrity=True, ignore_index = True)

# %%
CRPhisNovo.drop_duplicates()
# Out:
#        Campus Identificador   Ano Semestre Cd_Disciplina Codigo_Conceito  \
# 0         CRP      30003576  2014        1       ADE 101             NaN
# 1         CRP      30003576  2014        1       ADE 191             NaN
# 2         CRP      30003576  2014        1       CIC 100             NaN
# 3         CRP      30003576  2014        1       CRP 091               S
# 4         CRP      30003576  2014        1       CRP 191             NaN
# ...       ...           ...   ...      ...           ...             ...
# 159638    CRP      30009987  2021        1      SIN 323                T
# 159639    CRP      30009987  2021        1      SIN 352                T
# 159640    CRP      30009987  2021        1      SIN 392                T
# 159641    CRP      30009987  2021        1      SIN 394
# 159642    CRP      30009987  2021        1      SIN 421                T
#
#         Nota Faltas_Teorica Faltas_Pratica
# 0         50              2              0
# ...

# %%
AlunosSIquery = CRPinfo.query('Codigo_Curso== 104' and 'Codigo_Curso== 105')
AlunosSI = pd.DataFrame(data=AlunosSIquery)

# %%
AlunosSI.to_csv("AlunosSI.csv")

# %%
matricula = CRPhisNovo['Identificador']
matriculaSI = AlunosSI['Identificador']
matriculaSI.to_csv("matriculasi.csv")

# %%
dfmat = pd.DataFrame(data = matriculaSI)

# %%
dfFim = pd.merge(AlunosSI, CRPhisNovo, how= 'outer', on = 'Identificador')
dfFim.dropna(subset=["Curso"])
# Out:
#      Campus_x Identificador  Codigo_Curso                             Curso  \
# 0         CRP    30004155.0         105.0  Sistemas de Informacao - Noturno
# 1         CRP    30004170.0         105.0  Sistemas de Informacao - Noturno
# 2         CRP    30004183.0         105.0  Sistemas de Informacao - Noturno
# 3         CRP    30004216.0         105.0  Sistemas de Informacao - Noturno
# 4         CRP    30004221.0         105.0  Sistemas de Informacao - Noturno
# ...       ...           ...           ...                               ...
# 5147      CRP    30009987.0         105.0  Sistemas de Informacao - Noturno
# 5148      CRP    30009987.0         105.0  Sistemas de Informacao - Noturno
# 5149      CRP    30009987.0         105.0  Sistemas de Informacao - Noturno
# 5150      CRP    30009987.0         105.0  Sistemas de Informacao - Noturno
# 5151      CRP    30009987.0         105.0  Sistemas de Informacao - Noturno
#
# ...

# %%
alunoLog = CRPhisNovo.query('Cd_Disciplina == "SIN 130"')
alunoSI = alunoLog['Identificador']
HiSI = CRPhisNovo.merge(alunoSI)

# %%
#HiSI = CRPhisNovo.merge(dfmat)
HiSI.to_csv("HistoricoSICRP.csv")

# %%
HiSI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12910 entries, 0 to 12909
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Campus           12910 non-null  object
#  1   Identificador    12910 non-null  object
#  2   Ano              12910 non-null  object
#  3   Semestre         12910 non-null  object
#  4   Cd_Disciplina    12910 non-null  object
#  5   Codigo_Conceito  1786 non-null   object
#  6   Nota             12673 non-null  object
#  7   Faltas_Teorica   10817 non-null  object
#  8   Faltas_Pratica   10817 non-null  object
# dtypes: object(9)
# memory usage: 1008.6+ KB

# %%
SIhis = pd.DataFrame(data = HiSI)

# %%
HiSI.query('Ano == "2014"'and 'Cd_Disciplina == "SIN 110")
# Out:
#   File "C:\Users\Cliente\AppData\Local\Temp/ipykernel_3460/2841605626.py", line 1
#     HiSI.query('Ano == "2014"'and 'Cd_Disciplina == "SIN 110")
#                                                               ^
# SyntaxError: EOL while scanning string literal
